# %% [markdown]
# # Lab 1: Introduction to Natural Language Processing
# Mohammed Naif Alhadi - 224 - 7563 - 7MA2

# %% [markdown]
# ## Task 1: Dataset Search
# - **Dataset Type:** CSV
# - **Dataset Name:** Apple Twitter Sentiment Texts
# - **Source:** Kaggle (https://www.kaggle.com/datasets/seriousran/appletwittersentimenttexts)

# %%
import pandas as pd

# 1. Load the CSV dataset
df = pd.read_csv('apple-twitter-sentiment-texts.csv')

# 2. Display dataset information and summary
print("Dataset Shape (Rows, Columns):", df.shape)
print("\nDataset Information:")
df.info()

# 3. Preview the first 5 rows
df.head()
# Out:
# Dataset Shape (Rows, Columns): (1630, 2)
#
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1630 entries, 0 to 1629
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   text       1630 non-null   object
#  1   sentiment  1630 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 25.6+ KB
#                                                 text  sentiment
# 0  Wow. Yall needa step it up @Apple RT @heynyla:...         -1
# 1  What Happened To Apple Inc?   http://t.co/FJEX...          0
# 2  Thank u @apple I can now compile all of the pi...          1
# 3  The oddly uplifting story of the Apple co-foun...          0
# 4  @apple can i exchange my iphone for a differen...          0
